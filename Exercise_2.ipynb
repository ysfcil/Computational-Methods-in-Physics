# %%
import numpy as np
import matplotlib.pyplot as plt
import csv

CSVData = open("new_file.csv")
Array2d_result = np.genfromtxt(CSVData, delimiter=",")
v1 = np.linspace(0,100,100)
v2 = np.linspace((0,100,100))

print(Array2d_result[0],Array2d_result[0][0])
for i in range(len(Array2d_result)):
    v1[i] = [Array2d_result[i][0]]
    v2[i] = [Array2d_result[i][1]]
print(v1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[54], line 8
#       6 Array2d_result = np.genfromtxt(CSVData, delimiter=",")
#       7 v1 = np.linspace(0,100,100)
# ----> 8 v2 = np.linspace((0,100,100))
#      10 print(Array2d_result[0],Array2d_result[0][0])
#      11 for i in range(len(Array2d_result)):
#
# File <__array_function__ internals>:198, in linspace(*args, **kwargs)
#
# TypeError: linspace() missing 1 required positional argument: 'stop'

# %%
v1 = np.linspace(1, 100,100)
v2 = np.random.rand(100)
plt.plot(v1, v2)

# %%
def findeverything(my_vector):
    my_max = my_vector.max()
    my_min = my_vector.min()
    my_average = my_max/(len(my_vector))
    star_derv = np.std(v2)
    print("Max value is {}\nMin value is {}\nAverage value is {}\nStandart deviation is{}".format(my_max,my_min,my_average,star_derv))

# %%
findeverything(v2)
# Out:
# Max value is 0.9951764676689031
# Min value is 0.011063591476533352
# Average value is 0.009951764676689031
# Standart deviation is0.3104798136587504
