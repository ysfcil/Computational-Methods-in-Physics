# %%
import numpy as np
import matplotlib.pyplot as plt
import time
import random

# %%
points = 0
points_ = []
for number_tried in range(1,100):
 points = 0
 for i in range(34):
    match_result = np.random.random(1)
    if match_result <0.4:
        points += 3
    if match_result <0.5:
        points += 1
    points_.append(points)
plt.plot(range(0, len(points_)), points_)
